# %%
import pandas as pd

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n£mero de serie del volumen es: E469-A03C
#
#  Directorio de C:\Users\Dell‡\Documents\proyectPython\Python-basicos-02
#
# 10/03/2022  18:29    <DIR>          .
# 10/03/2022  18:29    <DIR>          ..
# 10/03/2022  18:09    <DIR>          .ipynb_checkpoints
# 10/03/2022  18:23    <DIR>          data
# 10/03/2022  18:29            15.923 Ejemplo-Pandas-01.ipynb
# 10/03/2022  18:24            20.702 Ejemplo-Pandas-01-Copy1.ipynb
# 10/03/2022  17:17             2.034 Ejemplo-Pandas-02.ipynb
# 10/03/2022  17:17    <DIR>          images
# 10/03/2022  17:17               721 README.md
#                4 archivos         39.380 bytes
#                5 dirs  815.744.196.608 bytes libres

# %%
ls data/
# Out:
# El modificador no es v lido: "".

# %%
data1 = pd.read_csv("data/data-mundial.csv")

# %%
data1.keys()
# Out:
# Index(['Unnamed: 0', 'ID', 'Numero', 'FIFADisplayName', 'Country', 'LastName',
#        'FirstName', 'ShirtName', 'DOB', 'POS', 'Club', 'Height', 'Caps',
#        'Goals'],
#       dtype='object')

# %%
# obtener los jugadores que tienen 5 o más goles
#data1 [data1['Goals']>=20]
# obtener los jugadores que tienen 5 goles con ID ==1
data1 [(data1['Goals']>5 )&(data1['ID']==1)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, ID, Numero, FIFADisplayName, Country, LastName, FirstName, ShirtName, DOB, POS, Club, Height, Caps, Goals]
# Index: []

# %%
# result = pd.merge(data1, data2, on="ID")

# %%
 #obtener los jugadores que tiene numero mayor a 3 y igual a 5 goles
data1 [(data1['Numero']>3 )&(data1['Goals']==5)]
# Out:
#      Unnamed: 0   ID  Numero    FIFADisplayName      Country  \
# 30           30   31       8     Massimo LUONGO    Australia
# 32           32   33      10       Robbie KRUSE    Australia
# 35           35   36      13         Aaron MOOY    Australia
# 56           56   57      11   Yannick CARRASCO      Belgium
# 60           60   61      15     Thomas MEUNIER      Belgium
# 64           64   65      19     Moussa DEMBELE      Belgium
# 67           67   68      22       Nacer CHADLI      Belgium
# 76           76   77       8     RENATO AUGUSTO       Brazil
# 200         200  201      17     MOHAMED ELNENY        Egypt
# 221         221  222      15        Gary CAHILL      England
# 257         257  258       5       Mats HUMMELS      Germany
# 289         289  290      14       Kari ARNASON      Iceland
# 296         296  297      21   Arnor TRAUSTASON      Iceland
# 382         382  383      16     Hector HERRERA       Mexico
# ...

# %%
# 
data1[ (data1['Goals']>5) & (data1['Country']=="Uruguay") ]
# Out:
#      Unnamed: 0   ID  Numero     FIFADisplayName  Country           LastName  \
# 715         715  716       3         Diego GODIN  Uruguay         GODIN LEAL
# 719         719  720       7  Cristian RODRIGUEZ  Uruguay  RODRIGUEZ BAROTTI
# 721         721  722       9         Luis SUAREZ  Uruguay        SUAREZ DIAZ
# 733         733  734      21      Edinson CAVANI  Uruguay       CAVANI GOMEZ
#
#             FirstName     ShirtName         DOB POS  \
# 715     Diego Roberto      D. GODIN  16.02.1986  DF
# 719  Cristian Gabriel  C. RODRIGUEZ  30.09.1985  MF
# 721      Luis Alberto     L. SUAREZ  24.01.1987  FW
# 733   Edinson Roberto     E. CAVANI  14.02.1987  FW
#
#                           Club  Height  Caps  Goals
# 715      Atlético Madrid (ESP)     185   116      8
# 719              Peñarol (URU)     178   105     11
# 721         FC Barcelona (ESP)     182    98     51
# 733  Paris Saint-Germain (FRA)     188   101     42

# %%
# 
data1[ (data1['Goals']>5) & (data1['Country'].isin(["Uruguay", "Argentina", "Colombia"]))]
# Out:
#      Unnamed: 0   ID  Numero     FIFADisplayName    Country  \
# 6             6    7       7         Ever BANEGA  Argentina
# 8             8    9       9     Gonzalo HIGUAIN  Argentina
# 9             9   10      10        Lionel MESSI  Argentina
# 10           10   11      11      Angel DI MARIA  Argentina
# 18           18   19      19       Sergio AGUERO  Argentina
# 98           98   99       7        Carlos BACCA   Colombia
# 99           99  100       8        Abel AGUILAR   Colombia
# 100         100  101       9      Radamel FALCAO   Colombia
# 101         101  102      10     James RODRIGUEZ   Colombia
# 102         102  103      11       Juan CUADRADO   Colombia
# 715         715  716       3         Diego GODIN    Uruguay
# 719         719  720       7  Cristian RODRIGUEZ    Uruguay
# 721         721  722       9         Luis SUAREZ    Uruguay
# 733         733  734      21      Edinson CAVANI    Uruguay
#
# ...
